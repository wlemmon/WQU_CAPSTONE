# %%
import sys
import importlib
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")
import dataframe_image as dfi
import pandas as pd
dt = pd.to_datetime
try:
    importlib.reload(sys.modules['experiments'])
except Exception as e:
    print(e)
from experiments import *

# %%
universe = prepare_universe()
highbm = universe[universe.bm_quintile==4]
bulls, bears = classify_bulls_and_bears()

# %%
ports = compute_bull_bear_portfolios(highbm.query('symbol != "VIAC"'), bulls, bears)
# Out:
# p0 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p1 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p2 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p3 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p4 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p5 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p6 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p7 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p8 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p9 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# plo 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# pmid 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# phi 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# all 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p0 1987 actual earnings report year used 1986
# 1987 0 cannot run experiment
# p1 1987 actual earnings report year used 1986
# 1987 0 cannot run experiment
# p2 1987 actual earnings report year used 1986
# 1987 0 cannot run experiment
# p3 1987 actual earnings report year used 1986
# 1987-08-26 1987-12-03 filter= p3 pfolio_size 2 pool size 2
# p4 1987 actual earnings report year used 1986
# 1987-08-26 1987-12-03 filter= p4 pfolio_size 2 pool size 2
# p5 1987 actual earnings report year used 1986
# 1987-08-26 1987-12-03 filter= p5 pfolio_size 3 pool size 3
# p6 1987 actual earnings report year used 1986
# 1987-08-26 1987-12-03 filter= p6 pfolio_size 1 pool size 1
# p7 1987 actual earnings report year used 1986
# 1987-08-26 1987-12-03 filter= p7 pfolio_size 1 pool size 1
# p8 1987 actual earnings report year used 1986
# 1987 0 cannot run experiment
# p9 1987 actual earnings report year used 1986
# 1987 0 cannot run experiment
# plo 1987 actual earnings report year used 1986
# 1987 0 cannot run experiment
# pmid 1987 actual earnings report year used 1986
# 1987-08-26 1987-12-03 filter= pmid pfolio_size 9 pool size 9
# phi 1987 actual earnings report year used 1986
# 1987 0 cannot run experiment
# all 1987 actual earnings report year used 1986
# 1987-08-26 1987-12-03 filter= all pfolio_size 9 pool size 9
# p0 2000 actual earnings report year used 2001
# 2000 0 cannot run experiment
# p1 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p1 pfolio_size 2 pool size 2
# p2 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p2 pfolio_size 10 pool size 14
# p3 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p3 pfolio_size 10 pool size 38
# p4 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p4 pfolio_size 10 pool size 49
# p5 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p5 pfolio_size 10 pool size 64
# p6 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p6 pfolio_size 10 pool size 71
# p7 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p7 pfolio_size 10 pool size 55
# p8 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p8 pfolio_size 10 pool size 25
# p9 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= p9 pfolio_size 1 pool size 1
# plo 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= plo pfolio_size 2 pool size 2
# pmid 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= pmid pfolio_size 10 pool size 291
# phi 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= phi pfolio_size 10 pool size 26
# all 2000 actual earnings report year used 1999
# 2000-03-27 2002-10-08 filter= all pfolio_size 10 pool size 319
# p0 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p0 pfolio_size 1 pool size 1
# p1 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p1 pfolio_size 7 pool size 7
# p2 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p2 pfolio_size 10 pool size 19
# p3 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p3 pfolio_size 10 pool size 58
# p4 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p4 pfolio_size 10 pool size 87
# p5 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p5 pfolio_size 10 pool size 113
# p6 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p6 pfolio_size 10 pool size 96
# p7 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p7 pfolio_size 10 pool size 71
# p8 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p8 pfolio_size 10 pool size 22
# p9 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= p9 pfolio_size 4 pool size 4
# plo 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= plo pfolio_size 8 pool size 8
# pmid 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= pmid pfolio_size 10 pool size 444
# phi 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= phi pfolio_size 10 pool size 26
# all 2007 actual earnings report year used 2006
# 2007-10-10 2009-03-06 filter= all pfolio_size 10 pool size 478
# p0 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p0 pfolio_size 5 pool size 5
# p1 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p1 pfolio_size 10 pool size 36
# p2 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p2 pfolio_size 10 pool size 77
# p3 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p3 pfolio_size 10 pool size 137
# p4 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p4 pfolio_size 10 pool size 190
# p5 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p5 pfolio_size 10 pool size 220
# p6 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p6 pfolio_size 10 pool size 204
# p7 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p7 pfolio_size 10 pool size 110
# p8 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p8 pfolio_size 10 pool size 41
# p9 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= p9 pfolio_size 3 pool size 3
# plo 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= plo pfolio_size 10 pool size 41
# pmid 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= pmid pfolio_size 10 pool size 938
# phi 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= phi pfolio_size 10 pool size 44
# all 2020 actual earnings report year used 2019
# 2020-02-20 2020-03-20 filter= all pfolio_size 10 pool size 1023
# p0 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p0 pfolio_size 10 pool size 112
# p1 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p1 pfolio_size 10 pool size 194
# p2 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p2 pfolio_size 10 pool size 176
# p3 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p3 pfolio_size 10 pool size 187
# p4 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p4 pfolio_size 10 pool size 178
# p5 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p5 pfolio_size 10 pool size 194
# p6 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p6 pfolio_size 10 pool size 227
# p7 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p7 pfolio_size 10 pool size 113
# p8 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p8 pfolio_size 10 pool size 48
# p9 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= p9 pfolio_size 5 pool size 5
# plo 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= plo pfolio_size 10 pool size 306
# pmid 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= pmid pfolio_size 10 pool size 1075
# phi 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= phi pfolio_size 10 pool size 53
# all 2022 actual earnings report year used 2021
# 2022-01-04 2022-10-11 filter= all pfolio_size 10 pool size 1434
# p0 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p1 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p2 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p3 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p4 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p5 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p6 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p7 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p8 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p9 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# plo 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# pmid 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# phi 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# all 1980 actual earnings report year used 1979
# 1980 0 cannot run experiment
# p0 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p1 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p2 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p3 1982 actual earnings report year used 1985
# 1982-08-12 1987-08-25 filter= p3 pfolio_size 3 pool size 3
# p4 1982 actual earnings report year used 1985
# 1982-08-12 1987-08-25 filter= p4 pfolio_size 3 pool size 3
# p5 1982 actual earnings report year used 1985
# 1982-08-12 1987-08-25 filter= p5 pfolio_size 1 pool size 1
# p6 1982 actual earnings report year used 1986
# 1982-08-12 1987-08-25 filter= p6 pfolio_size 1 pool size 1
# p7 1982 actual earnings report year used 1984
# 1982-08-12 1987-08-25 filter= p7 pfolio_size 1 pool size 1
# p8 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p9 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# plo 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# pmid 1982 actual earnings report year used 1984
# 1982-08-12 1987-08-25 filter= pmid pfolio_size 1 pool size 1
# phi 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# all 1982 actual earnings report year used 1984
# 1982-08-12 1987-08-25 filter= all pfolio_size 1 pool size 1
# p0 1987 actual earnings report year used 1991
# 1987-12-04 2000-03-24 filter= p0 pfolio_size 1 pool size 1
# p1 1987 actual earnings report year used 1989
# 1987-12-04 2000-03-24 filter= p1 pfolio_size 3 pool size 3
# p2 1987 actual earnings report year used 1987
# 1987-12-04 2000-03-24 filter= p2 pfolio_size 1 pool size 1
# p3 1987 actual earnings report year used 1986
# 1987-12-04 2000-03-24 filter= p3 pfolio_size 2 pool size 2
# p4 1987 actual earnings report year used 1986
# 1987-12-04 2000-03-24 filter= p4 pfolio_size 2 pool size 2
# p5 1987 actual earnings report year used 1986
# 1987-12-04 2000-03-24 filter= p5 pfolio_size 3 pool size 3
# p6 1987 actual earnings report year used 1986
# 1987-12-04 2000-03-24 filter= p6 pfolio_size 1 pool size 1
# p7 1987 actual earnings report year used 1986
# 1987-12-04 2000-03-24 filter= p7 pfolio_size 1 pool size 1
# p8 1987 actual earnings report year used 1989
# 1987-12-04 2000-03-24 filter= p8 pfolio_size 3 pool size 3
# p9 1987 actual earnings report year used 1989
# 1987-12-04 2000-03-24 filter= p9 pfolio_size 1 pool size 1
# plo 1987 actual earnings report year used 1989
# 1987-12-04 2000-03-24 filter= plo pfolio_size 3 pool size 3
# pmid 1987 actual earnings report year used 1986
# 1987-12-04 2000-03-24 filter= pmid pfolio_size 9 pool size 9
# phi 1987 actual earnings report year used 1989
# 1987-12-04 2000-03-24 filter= phi pfolio_size 4 pool size 4
# all 1987 actual earnings report year used 1986
# 1987-12-04 2000-03-24 filter= all pfolio_size 9 pool size 9
# p0 2002 actual earnings report year used 2005
# 2002-10-09 2007-10-09 filter= p0 pfolio_size 2 pool size 2
# p1 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p1 pfolio_size 8 pool size 8
# p2 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p2 pfolio_size 10 pool size 16
# p3 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p3 pfolio_size 10 pool size 40
# p4 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p4 pfolio_size 10 pool size 76
# p5 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p5 pfolio_size 10 pool size 67
# p6 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p6 pfolio_size 10 pool size 70
# p7 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p7 pfolio_size 10 pool size 52
# p8 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p8 pfolio_size 10 pool size 16
# p9 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= p9 pfolio_size 4 pool size 4
# plo 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= plo pfolio_size 8 pool size 8
# pmid 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= pmid pfolio_size 10 pool size 321
# phi 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= phi pfolio_size 10 pool size 20
# all 2002 actual earnings report year used 2001
# 2002-10-09 2007-10-09 filter= all pfolio_size 10 pool size 349
# p0 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p0 pfolio_size 4 pool size 4
# p1 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p1 pfolio_size 10 pool size 12
# p2 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p2 pfolio_size 10 pool size 24
# p3 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p3 pfolio_size 10 pool size 62
# p4 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p4 pfolio_size 10 pool size 101
# p5 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p5 pfolio_size 10 pool size 109
# p6 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p6 pfolio_size 10 pool size 110
# p7 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p7 pfolio_size 10 pool size 71
# p8 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p8 pfolio_size 10 pool size 19
# p9 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= p9 pfolio_size 1 pool size 1
# plo 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= plo pfolio_size 10 pool size 16
# pmid 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= pmid pfolio_size 10 pool size 477
# phi 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= phi pfolio_size 10 pool size 20
# all 2009 actual earnings report year used 2008
# 2009-03-09 2020-02-19 filter= all pfolio_size 10 pool size 513
# p0 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p0 pfolio_size 5 pool size 5
# p1 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p1 pfolio_size 10 pool size 36
# p2 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p2 pfolio_size 10 pool size 77
# p3 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p3 pfolio_size 10 pool size 137
# p4 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p4 pfolio_size 10 pool size 190
# p5 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p5 pfolio_size 10 pool size 220
# p6 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p6 pfolio_size 10 pool size 204
# p7 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p7 pfolio_size 10 pool size 110
# p8 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p8 pfolio_size 10 pool size 41
# p9 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= p9 pfolio_size 3 pool size 3
# plo 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= plo pfolio_size 10 pool size 41
# pmid 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= pmid pfolio_size 10 pool size 938
# phi 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= phi pfolio_size 10 pool size 44
# all 2020 actual earnings report year used 2019
# 2020-03-23 2022-01-03 filter= all pfolio_size 10 pool size 1023
# p0 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p0 pfolio_size 10 pool size 112
# p1 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p1 pfolio_size 10 pool size 194
# p2 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p2 pfolio_size 10 pool size 176
# p3 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p3 pfolio_size 10 pool size 187
# p4 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p4 pfolio_size 10 pool size 178
# p5 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p5 pfolio_size 10 pool size 194
# p6 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p6 pfolio_size 10 pool size 227
# p7 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p7 pfolio_size 10 pool size 113
# p8 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p8 pfolio_size 10 pool size 48
# p9 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= p9 pfolio_size 5 pool size 5
# plo 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= plo pfolio_size 10 pool size 306
# pmid 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= pmid pfolio_size 10 pool size 1075
# phi 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= phi pfolio_size 10 pool size 53
# all 2022 actual earnings report year used 2021
# 2022-10-12 2023-12-15 filter= all pfolio_size 10 pool size 1434

# %%
midpoint = pd.to_datetime(ports.start) + ((pd.to_datetime(ports.end) - pd.to_datetime(ports.start))/2)
p2 = ports.set_index(midpoint).query('group == "all"')
market_plot(bears)
plt.title('S&P 500, Bulls & Bears, Market Returns')
ax2 = plt.twinx()
fig = sns.boxplot(data=p2, x=p2.index, y="m_ret", ax=ax2, native_scale=True, width=1, fliersize=0)#, col='group')

# %% [markdown]
# ## Demonstrate Non-lookahead (lagging) bull bear classification confounds problem with separate problem of regime classification

# %%
bulls1, bears1 = classify_bulls_and_bears_nonlookahead()
display(bears1)
display(bulls1)
# Out:
#              min        max
# bearn
# 0     1982-02-22 1982-09-14
# 1     1987-10-19 1988-03-08
# 2     2001-03-12 2001-12-05
# 3     2002-07-10 2002-08-22
# 4     2008-07-09 2008-12-08
# 5     2009-02-23 2009-03-25
# 6     2020-03-12 2020-04-13
# 7     2022-06-13 2023-06-08
#              min        max
# bearn
# 0     1980-01-02 1982-02-22
# 1     1982-09-15 1987-10-19
# 2     1988-03-09 2001-03-12
# 3     2001-12-06 2002-07-10
# 4     2002-08-23 2008-07-09
# 5     2008-12-09 2009-02-23
# 6     2009-03-26 2020-03-12
# 7     2020-04-14 2022-06-13
# 8     2023-06-09 2023-12-15

# %%
ports1 = compute_bull_bear_portfolios(highbm.query('symbol != "VIAC"'), bulls1, bears1)
# Out:
# p0 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p1 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p2 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p3 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p4 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p5 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p6 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p7 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p8 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p9 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# plo 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# phi 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# all 1982 actual earnings report year used 1981
# 1982 0 cannot run experiment
# p0 1987 actual earnings report year used 1987
# 1987 0 cannot run experiment
# p1 1987 actual earnings report year used 1987
# 1987 0 cannot run experiment
# p2 1987 actual earnings report year used 1987
# 1987-10-19 1988-03-08 filter= p2 pfolio_size 1 pool size 1
# p3 1987 actual earnings report year used 1986
# 1987-10-19 1988-03-08 filter= p3 pfolio_size 2 pool size 2
# p4 1987 actual earnings report year used 1986
# 1987-10-19 1988-03-08 filter= p4 pfolio_size 2 pool size 2
# p5 1987 actual earnings report year used 1986
# 1987-10-19 1988-03-08 filter= p5 pfolio_size 3 pool size 3
# p6 1987 actual earnings report year used 1986
# 1987-10-19 1988-03-08 filter= p6 pfolio_size 1 pool size 1
# p7 1987 actual earnings report year used 1986
# 1987-10-19 1988-03-08 filter= p7 pfolio_size 1 pool size 1
# p8 1987 actual earnings report year used 1987
# 1987 0 cannot run experiment
# p9 1987 actual earnings report year used 1987
# 1987 0 cannot run experiment
# plo 1987 actual earnings report year used 1987
# 1987 0 cannot run experiment
# phi 1987 actual earnings report year used 1987
# 1987 0 cannot run experiment
# all 1987 actual earnings report year used 1986
# 1987-10-19 1988-03-08 filter= all pfolio_size 9 pool size 9
# p0 2001 actual earnings report year used 2000
# 2001 0 cannot run experiment
# p1 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p1 pfolio_size 5 pool size 5
# p2 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p2 pfolio_size 10 pool size 15
# p3 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p3 pfolio_size 10 pool size 38
# p4 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p4 pfolio_size 10 pool size 54
# p5 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p5 pfolio_size 10 pool size 83
# p6 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p6 pfolio_size 10 pool size 83
# p7 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p7 pfolio_size 10 pool size 50
# p8 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p8 pfolio_size 10 pool size 14
# p9 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= p9 pfolio_size 3 pool size 3
# plo 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= plo pfolio_size 5 pool size 5
# phi 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= phi pfolio_size 10 pool size 17
# all 2001 actual earnings report year used 2000
# 2001-03-12 2001-12-05 filter= all pfolio_size 10 pool size 345
# p0 2002 actual earnings report year used 2001
# 2002 0 cannot run experiment
# p1 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p1 pfolio_size 8 pool size 8
# p2 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p2 pfolio_size 10 pool size 16
# p3 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p3 pfolio_size 10 pool size 40
# p4 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p4 pfolio_size 10 pool size 76
# p5 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p5 pfolio_size 10 pool size 67
# p6 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p6 pfolio_size 10 pool size 70
# p7 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p7 pfolio_size 10 pool size 52
# p8 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p8 pfolio_size 10 pool size 16
# p9 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= p9 pfolio_size 4 pool size 4
# plo 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= plo pfolio_size 8 pool size 8
# phi 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= phi pfolio_size 10 pool size 20
# all 2002 actual earnings report year used 2001
# 2002-07-10 2002-08-22 filter= all pfolio_size 10 pool size 349
# p0 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p0 pfolio_size 3 pool size 3
# p1 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p1 pfolio_size 10 pool size 13
# p2 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p2 pfolio_size 10 pool size 25
# p3 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p3 pfolio_size 10 pool size 65
# p4 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p4 pfolio_size 10 pool size 100
# p5 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p5 pfolio_size 10 pool size 110
# p6 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p6 pfolio_size 10 pool size 93
# p7 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p7 pfolio_size 10 pool size 63
# p8 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p8 pfolio_size 10 pool size 26
# p9 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= p9 pfolio_size 4 pool size 4
# plo 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= plo pfolio_size 10 pool size 16
# phi 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= phi pfolio_size 10 pool size 30
# all 2008 actual earnings report year used 2007
# 2008-07-09 2008-12-08 filter= all pfolio_size 10 pool size 502
# p0 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p0 pfolio_size 4 pool size 4
# p1 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p1 pfolio_size 10 pool size 12
# p2 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p2 pfolio_size 10 pool size 24
# p3 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p3 pfolio_size 10 pool size 62
# p4 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p4 pfolio_size 10 pool size 101
# p5 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p5 pfolio_size 10 pool size 109
# p6 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p6 pfolio_size 10 pool size 110
# p7 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p7 pfolio_size 10 pool size 71
# p8 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p8 pfolio_size 10 pool size 19
# p9 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= p9 pfolio_size 1 pool size 1
# plo 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= plo pfolio_size 10 pool size 16
# phi 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= phi pfolio_size 10 pool size 20
# all 2009 actual earnings report year used 2008
# 2009-02-23 2009-03-25 filter= all pfolio_size 10 pool size 513
# p0 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p0 pfolio_size 5 pool size 5
# p1 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p1 pfolio_size 10 pool size 36
# p2 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p2 pfolio_size 10 pool size 77
# p3 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p3 pfolio_size 10 pool size 137
# p4 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p4 pfolio_size 10 pool size 190
# p5 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p5 pfolio_size 10 pool size 220
# p6 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p6 pfolio_size 10 pool size 204
# p7 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p7 pfolio_size 10 pool size 110
# p8 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p8 pfolio_size 10 pool size 41
# p9 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= p9 pfolio_size 3 pool size 3
# plo 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= plo pfolio_size 10 pool size 41
# phi 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= phi pfolio_size 10 pool size 44
# all 2020 actual earnings report year used 2019
# 2020-03-12 2020-04-13 filter= all pfolio_size 10 pool size 1023
# p0 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p0 pfolio_size 10 pool size 112
# p1 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p1 pfolio_size 10 pool size 194
# p2 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p2 pfolio_size 10 pool size 176
# p3 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p3 pfolio_size 10 pool size 187
# p4 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p4 pfolio_size 10 pool size 178
# p5 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p5 pfolio_size 10 pool size 194
# p6 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p6 pfolio_size 10 pool size 227
# p7 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p7 pfolio_size 10 pool size 113
# p8 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p8 pfolio_size 10 pool size 48
# p9 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= p9 pfolio_size 5 pool size 5
# plo 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= plo pfolio_size 10 pool size 306
# phi 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= phi pfolio_size 10 pool size 53
# all 2022 actual earnings report year used 2021
# 2022-06-13 2023-06-08 filter= all pfolio_size 10 pool size 1434
# p0 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p1 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p2 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p3 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p4 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p5 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p6 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p7 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p8 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p9 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# plo 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# phi 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# all 1980 actual earnings report year used 1981
# 1980 0 cannot run experiment
# p0 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p1 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p2 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p3 1982 actual earnings report year used 1985
# 1982-09-15 1987-10-19 filter= p3 pfolio_size 3 pool size 3
# p4 1982 actual earnings report year used 1985
# 1982-09-15 1987-10-19 filter= p4 pfolio_size 3 pool size 3
# p5 1982 actual earnings report year used 1985
# 1982-09-15 1987-10-19 filter= p5 pfolio_size 1 pool size 1
# p6 1982 actual earnings report year used 1986
# 1982-09-15 1987-10-19 filter= p6 pfolio_size 1 pool size 1
# p7 1982 actual earnings report year used 1984
# 1982-09-15 1987-10-19 filter= p7 pfolio_size 1 pool size 1
# p8 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# p9 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# plo 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# phi 1982 actual earnings report year used 1986
# 1982 0 cannot run experiment
# all 1982 actual earnings report year used 1984
# 1982-09-15 1987-10-19 filter= all pfolio_size 1 pool size 1
# p0 1988 actual earnings report year used 1991
# 1988-03-09 2001-03-12 filter= p0 pfolio_size 1 pool size 1
# p1 1988 actual earnings report year used 1989
# 1988-03-09 2001-03-12 filter= p1 pfolio_size 3 pool size 3
# p2 1988 actual earnings report year used 1987
# 1988-03-09 2001-03-12 filter= p2 pfolio_size 1 pool size 1
# p3 1988 actual earnings report year used 1987
# 1988-03-09 2001-03-12 filter= p3 pfolio_size 1 pool size 1
# p4 1988 actual earnings report year used 1987
# 1988-03-09 2001-03-12 filter= p4 pfolio_size 1 pool size 1
# p5 1988 actual earnings report year used 1987
# 1988-03-09 2001-03-12 filter= p5 pfolio_size 1 pool size 1
# p6 1988 actual earnings report year used 1988
# 1988-03-09 2001-03-12 filter= p6 pfolio_size 2 pool size 2
# p7 1988 actual earnings report year used 1987
# 1988-03-09 2001-03-12 filter= p7 pfolio_size 1 pool size 1
# p8 1988 actual earnings report year used 1989
# 1988-03-09 2001-03-12 filter= p8 pfolio_size 3 pool size 3
# p9 1988 actual earnings report year used 1989
# 1988-03-09 2001-03-12 filter= p9 pfolio_size 1 pool size 1
# plo 1988 actual earnings report year used 1989
# 1988-03-09 2001-03-12 filter= plo pfolio_size 3 pool size 3
# phi 1988 actual earnings report year used 1989
# 1988-03-09 2001-03-12 filter= phi pfolio_size 4 pool size 4
# all 1988 actual earnings report year used 1987
# 1988-03-09 2001-03-12 filter= all pfolio_size 5 pool size 5
# p0 2001 actual earnings report year used 2001
# 2001 0 cannot run experiment
# p1 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p1 pfolio_size 5 pool size 5
# p2 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p2 pfolio_size 10 pool size 15
# p3 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p3 pfolio_size 10 pool size 38
# p4 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p4 pfolio_size 10 pool size 54
# p5 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p5 pfolio_size 10 pool size 83
# p6 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p6 pfolio_size 10 pool size 83
# p7 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p7 pfolio_size 10 pool size 50
# p8 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p8 pfolio_size 10 pool size 14
# p9 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= p9 pfolio_size 3 pool size 3
# plo 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= plo pfolio_size 5 pool size 5
# phi 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= phi pfolio_size 10 pool size 17
# all 2001 actual earnings report year used 2000
# 2001-12-06 2002-07-10 filter= all pfolio_size 10 pool size 345
# p0 2002 actual earnings report year used 2005
# 2002-08-23 2008-07-09 filter= p0 pfolio_size 2 pool size 2
# p1 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p1 pfolio_size 8 pool size 8
# p2 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p2 pfolio_size 10 pool size 16
# p3 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p3 pfolio_size 10 pool size 40
# p4 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p4 pfolio_size 10 pool size 76
# p5 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p5 pfolio_size 10 pool size 67
# p6 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p6 pfolio_size 10 pool size 70
# p7 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p7 pfolio_size 10 pool size 52
# p8 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p8 pfolio_size 10 pool size 16
# p9 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= p9 pfolio_size 4 pool size 4
# plo 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= plo pfolio_size 8 pool size 8
# phi 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= phi pfolio_size 10 pool size 20
# all 2002 actual earnings report year used 2001
# 2002-08-23 2008-07-09 filter= all pfolio_size 10 pool size 349
# p0 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p0 pfolio_size 3 pool size 3
# p1 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p1 pfolio_size 10 pool size 13
# p2 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p2 pfolio_size 10 pool size 25
# p3 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p3 pfolio_size 10 pool size 65
# p4 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p4 pfolio_size 10 pool size 100
# p5 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p5 pfolio_size 10 pool size 110
# p6 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p6 pfolio_size 10 pool size 93
# p7 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p7 pfolio_size 10 pool size 63
# p8 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p8 pfolio_size 10 pool size 26
# p9 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= p9 pfolio_size 4 pool size 4
# plo 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= plo pfolio_size 10 pool size 16
# phi 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= phi pfolio_size 10 pool size 30
# all 2008 actual earnings report year used 2007
# 2008-12-09 2009-02-23 filter= all pfolio_size 10 pool size 502
# p0 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p0 pfolio_size 4 pool size 4
# p1 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p1 pfolio_size 10 pool size 12
# p2 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p2 pfolio_size 10 pool size 24
# p3 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p3 pfolio_size 10 pool size 62
# p4 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p4 pfolio_size 10 pool size 101
# p5 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p5 pfolio_size 10 pool size 109
# p6 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p6 pfolio_size 10 pool size 110
# p7 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p7 pfolio_size 10 pool size 71
# p8 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p8 pfolio_size 10 pool size 19
# p9 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= p9 pfolio_size 1 pool size 1
# plo 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= plo pfolio_size 10 pool size 16
# phi 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= phi pfolio_size 10 pool size 20
# all 2009 actual earnings report year used 2008
# 2009-03-26 2020-03-12 filter= all pfolio_size 10 pool size 513
# p0 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p0 pfolio_size 5 pool size 5
# p1 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p1 pfolio_size 10 pool size 36
# p2 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p2 pfolio_size 10 pool size 77
# p3 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p3 pfolio_size 10 pool size 137
# p4 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p4 pfolio_size 10 pool size 190
# p5 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p5 pfolio_size 10 pool size 220
# p6 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p6 pfolio_size 10 pool size 204
# p7 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p7 pfolio_size 10 pool size 110
# p8 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p8 pfolio_size 10 pool size 41
# p9 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= p9 pfolio_size 3 pool size 3
# plo 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= plo pfolio_size 10 pool size 41
# phi 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= phi pfolio_size 10 pool size 44
# all 2020 actual earnings report year used 2019
# 2020-04-14 2022-06-13 filter= all pfolio_size 10 pool size 1023
# p0 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p0 pfolio_size 10 pool size 120
# p1 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p1 pfolio_size 10 pool size 122
# p2 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p2 pfolio_size 10 pool size 256
# p3 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p3 pfolio_size 10 pool size 235
# p4 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p4 pfolio_size 10 pool size 223
# p5 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p5 pfolio_size 10 pool size 208
# p6 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p6 pfolio_size 10 pool size 141
# p7 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p7 pfolio_size 10 pool size 82
# p8 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p8 pfolio_size 10 pool size 26
# p9 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= p9 pfolio_size 6 pool size 6
# plo 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= plo pfolio_size 10 pool size 242
# phi 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= phi pfolio_size 10 pool size 32
# all 2023 actual earnings report year used 2022
# 2023-06-09 2023-12-15 filter= all pfolio_size 10 pool size 1419

# %%
midpoint = dt(ports1.start) + ((dt(ports1.end) - dt(ports1.start))/2)
p2_2 = ports1.set_index(midpoint).query('group == "all"')
display(p2_2.head())
market_plot(bears1)
plt.title('S&P 500, Non-lookahead Bulls & Bears, Market Returns')
ax2 = plt.twinx()
fig = sns.boxplot(data=p2_2, x=p2_2.index, y="m_ret", ax=ax2, native_scale=True, width=5, fliersize=0)
# Out:
#                           start         end market group  raw_ret  \
# 1987-12-28 12:00:00  1987-10-19  1988-03-08   bear   all     0.12
# 1987-12-28 12:00:00  1987-10-19  1988-03-08   bear   all     0.12
# 1987-12-28 12:00:00  1987-10-19  1988-03-08   bear   all     0.12
# 1987-12-28 12:00:00  1987-10-19  1988-03-08   bear   all     0.12
# 1987-12-28 12:00:00  1987-10-19  1988-03-08   bear   all     0.12
#
#                      raw_ret_pos  raw_avg_ret  raw_avg_ret_pos   p0   p10  \
# 1987-12-28 12:00:00          1.0         0.02              1.0 -0.1 -0.04
# 1987-12-28 12:00:00          1.0         0.02              1.0 -0.1 -0.04
# 1987-12-28 12:00:00          1.0         0.02              1.0 -0.1 -0.04
# 1987-12-28 12:00:00          1.0         0.02              1.0 -0.1 -0.04
# 1987-12-28 12:00:00          1.0         0.02              1.0 -0.1 -0.04
#
#                       p25       p50   p75   p90   max  ma_ret  ma_ret_pos  \
# 1987-12-28 12:00:00 -0.02  4.75e-03  0.06  0.11  0.12   -0.07         0.0
# 1987-12-28 12:00:00 -0.02  4.75e-03  0.06  0.11  0.12   -0.07         0.0
# 1987-12-28 12:00:00 -0.02  4.75e-03  0.06  0.11  0.12   -0.07         0.0
# 1987-12-28 12:00:00 -0.02  4.75e-03  0.06  0.11  0.12   -0.07         0.0
# 1987-12-28 12:00:00 -0.02  4.75e-03  0.06  0.11  0.12   -0.07         0.0
#
#                      ma_avg_ret  ma_avg_ret_pos  m_ret  |P|
# 1987-12-28 12:00:00       -0.09             0.0   0.19    9
# 1987-12-28 12:00:00       -0.09             0.0   0.19    9
# 1987-12-28 12:00:00       -0.09             0.0   0.19    9
# 1987-12-28 12:00:00       -0.09             0.0   0.19    9
# 1987-12-28 12:00:00       -0.09             0.0   0.19    9

# %% [markdown]
# ## Back to original market regime classification

# %%
ports['covid_era'] = dt(ports.start) > dt('2018-01-01')
ports['midpoint'] = (dt(ports.start) + ((dt(ports.end) - dt(ports.start))/2))
# melt for sns
ports2 = pd.melt(ports, id_vars=['start', 'end', 'midpoint', 'market', 'group', 'covid_era', ], \
                 value_vars=['raw_ret', 'ma_ret', 'm_ret'], var_name='return_type')
# compute outliers
ports2 = identify_outliers(ports2, m=3)
ports2.head()
# Out:
#         start         end   midpoint market   group  covid_era return_type  \
# 0  1980-12-01  1982-08-11 1981-10-06   bear  market      False     raw_ret
# 1  1980-12-01  1982-08-11 1981-10-06   bear  market      False     raw_ret
# 2  1980-12-01  1982-08-11 1981-10-06   bear  market      False     raw_ret
# 3  1980-12-01  1982-08-11 1981-10-06   bear  market      False     raw_ret
# 4  1980-12-01  1982-08-11 1981-10-06   bear  market      False     raw_ret
#
#    value  grp_start_return_median  grp_start_return_median_dev  \
# 0  -0.16                    -0.16                          0.0
# 1  -0.16                    -0.16                          0.0
# 2  -0.16                    -0.16                          0.0
# 3  -0.16                    -0.16                          0.0
# 4  -0.16                    -0.16                          0.0
#
#    grp_start_return_median_mdev  outlier
# 0                           0.0    False
# 1                           0.0    False
# 2                           0.0    False
# 3                           0.0    False
# 4                           0.0    False

# %%
first_time_to_plot = pd.to_datetime('2000-01-01')
g = sns.catplot(data=
                ports2[(ports2.outlier == False)
                       & ports2.group.isin(['market', 'all', 'phi', 'plo'])
                        & (dt(ports2.start) > first_time_to_plot)],
            x='midpoint', 
            y="value", 
            native_scale=True, 
            width=1, 
            row='group', 
            kind='boxen',
            hue='return_type',
            zorder=1,
            height = 5,
            aspect = 3,
               )
df = get_hist(MARKET_TICKER)[['adjClose']]

for group, ax in g.axes_dict.items():
    ax.set(ylabel='Returns')
    plt.setp(ax.lines, zorder=1)
    plt.setp(ax.collections, zorder=1, label="")
    ax2 = ax.twinx()
    plt.sca(ax2)
    plt.setp(ax2.lines, zorder=2)
    plt.setp(ax2.collections, zorder=2, label="")
    no_label_market_plot(bears[bears['min'] > first_time_to_plot], df[df.index > first_time_to_plot], z=2)
plt.show()

# %%
sort_rule = {f'p{i}': i for i in range(10)}
sns.set(rc={'figure.figsize':(8.27, 5)})
p = sns.catplot(
    data=filter_pscores(ports2)
    .sort_values(by=['market'])
    .sort_values(by=['group'], key=lambda series: series.apply(lambda x: sort_rule[x])),
    y="value", hue='return_type', x='group',kind="box",
    showfliers = False,
    col='market',
)
plt.show()

# %%
pgroup = {
    "plo":"0:low",
    "pmid":"1:mid",
    "phi":"2:high"
}
ports2_temp = filter_pscore_groups(ports2).copy()
ports2_temp['group'] = ports2_temp.group.map(pgroup)
caption = ("One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals"
           " by F-Score group <br> Bull and Bear markets"
          )
d = (
    pd.pivot_table(
    data=ports2_temp,
    index=['return_type','group',], 
    columns=['market'], 
    aggfunc=['mean',p5,p10,p25,p50,p75,p90,pos,ES,MS], 
    values='value',
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)

display(d)
dfi.export(d,"bulls_bears_returns.png",max_cols=-1)
# Out:
# <style type="text/css">
# #T_c318a caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_c318a td {
#   font-family: Times New Roman;
# }
# #T_c318a th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_c318a">
#   <caption>One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score group <br> Bull and Bear markets</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c318a_level0_col0" class="col_heading level0 col0" colspan="2">mean</th>
#       <th id="T_c318a_level0_col2" class="col_heading level0 col2" colspan="2">p5</th>
#       <th id="T_c318a_level0_col4" class="col_heading level0 col4" colspan="2">p10</th>
#       <th id="T_c318a_level0_col6" class="col_heading level0 col6" colspan="2">p25</th>
#       <th id="T_c318a_level0_col8" class="col_heading level0 col8" colspan="2">p50</th>
#       <th id="T_c318a_level0_col10" class="col_heading level0 col10" colspan="2">p75</th>
#       <th id="T_c318a_level0_col12" class="col_heading level0 col12" colspan="2">p90</th>
#       <th id="T_c318a_level0_col14" class="col_heading level0 col14" colspan="2">pos</th>
#       <th id="T_c318a_level0_col16" class="col_heading level0 col16" colspan="2">ES</th>
#       <th id="T_c318a_level0_col18" class="col_heading level0 col18" colspan="2">MS</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >market</th>
#       <th id="T_c318a_level1_col0" class="col_heading level1 col0" >bear</th>
#       <th id="T_c318a_level1_col1" class="col_heading level1 col1" >bull</th>
#       <th id="T_c318a_level1_col2" class="col_heading level1 col2" >bear</th>
#       <th id="T_c318a_level1_col3" class="col_heading level1 col3" >bull</th>
#       <th id="T_c318a_level1_col4" class="col_heading level1 col4" >bear</th>
#       <th id="T_c318a_level1_col5" class="col_heading level1 col5" >bull</th>
#       <th id="T_c318a_level1_col6" class="col_heading level1 col6" >bear</th>
#       <th id="T_c318a_level1_col7" class="col_heading level1 col7" >bull</th>
#       <th id="T_c318a_level1_col8" class="col_heading level1 col8" >bear</th>
#       <th id="T_c318a_level1_col9" class="col_heading level1 col9" >bull</th>
#       <th id="T_c318a_level1_col10" class="col_heading level1 col10" >bear</th>
#       <th id="T_c318a_level1_col11" class="col_heading level1 col11" >bull</th>
#       <th id="T_c318a_level1_col12" class="col_heading level1 col12" >bear</th>
#       <th id="T_c318a_level1_col13" class="col_heading level1 col13" >bull</th>
#       <th id="T_c318a_level1_col14" class="col_heading level1 col14" >bear</th>
#       <th id="T_c318a_level1_col15" class="col_heading level1 col15" >bull</th>
#       <th id="T_c318a_level1_col16" class="col_heading level1 col16" >bear</th>
#       <th id="T_c318a_level1_col17" class="col_heading level1 col17" >bull</th>
#       <th id="T_c318a_level1_col18" class="col_heading level1 col18" >bear</th>
#       <th id="T_c318a_level1_col19" class="col_heading level1 col19" >bull</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >return_type</th>
#       <th class="index_name level1" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c318a_level0_row0" class="row_heading level0 row0" rowspan="3">m_ret</th>
#       <th id="T_c318a_level1_row0" class="row_heading level1 row0" >0:low</th>
#       <td id="T_c318a_row0_col0" class="data row0 col0" >-0.30</td>
#       <td id="T_c318a_row0_col1" class="data row0 col1" >0.25</td>
#       <td id="T_c318a_row0_col2" class="data row0 col2" >-0.45</td>
#       <td id="T_c318a_row0_col3" class="data row0 col3" >0.15</td>
#       <td id="T_c318a_row0_col4" class="data row0 col4" >-0.45</td>
#       <td id="T_c318a_row0_col5" class="data row0 col5" >0.15</td>
#       <td id="T_c318a_row0_col6" class="data row0 col6" >-0.33</td>
#       <td id="T_c318a_row0_col7" class="data row0 col7" >0.16</td>
#       <td id="T_c318a_row0_col8" class="data row0 col8" >-0.27</td>
#       <td id="T_c318a_row0_col9" class="data row0 col9" >0.17</td>
#       <td id="T_c318a_row0_col10" class="data row0 col10" >-0.24</td>
#       <td id="T_c318a_row0_col11" class="data row0 col11" >0.27</td>
#       <td id="T_c318a_row0_col12" class="data row0 col12" >-0.23</td>
#       <td id="T_c318a_row0_col13" class="data row0 col13" >0.53</td>
#       <td id="T_c318a_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_c318a_row0_col15" class="data row0 col15" >1.00</td>
#       <td id="T_c318a_row0_col16" class="data row0 col16" >-0.45</td>
#       <td id="T_c318a_row0_col17" class="data row0 col17" >0.15</td>
#       <td id="T_c318a_row0_col18" class="data row0 col18" >-0.45</td>
#       <td id="T_c318a_row0_col19" class="data row0 col19" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_c318a_level1_row1" class="row_heading level1 row1" >1:mid</th>
#       <td id="T_c318a_row1_col0" class="data row1 col0" >-0.30</td>
#       <td id="T_c318a_row1_col1" class="data row1 col1" >0.26</td>
#       <td id="T_c318a_row1_col2" class="data row1 col2" >-0.45</td>
#       <td id="T_c318a_row1_col3" class="data row1 col3" >0.15</td>
#       <td id="T_c318a_row1_col4" class="data row1 col4" >-0.45</td>
#       <td id="T_c318a_row1_col5" class="data row1 col5" >0.15</td>
#       <td id="T_c318a_row1_col6" class="data row1 col6" >-0.30</td>
#       <td id="T_c318a_row1_col7" class="data row1 col7" >0.16</td>
#       <td id="T_c318a_row1_col8" class="data row1 col8" >-0.29</td>
#       <td id="T_c318a_row1_col9" class="data row1 col9" >0.22</td>
#       <td id="T_c318a_row1_col10" class="data row1 col10" >-0.25</td>
#       <td id="T_c318a_row1_col11" class="data row1 col11" >0.27</td>
#       <td id="T_c318a_row1_col12" class="data row1 col12" >-0.23</td>
#       <td id="T_c318a_row1_col13" class="data row1 col13" >0.53</td>
#       <td id="T_c318a_row1_col14" class="data row1 col14" >0.00</td>
#       <td id="T_c318a_row1_col15" class="data row1 col15" >1.00</td>
#       <td id="T_c318a_row1_col16" class="data row1 col16" >-0.45</td>
#       <td id="T_c318a_row1_col17" class="data row1 col17" >0.15</td>
#       <td id="T_c318a_row1_col18" class="data row1 col18" >-0.45</td>
#       <td id="T_c318a_row1_col19" class="data row1 col19" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_c318a_level1_row2" class="row_heading level1 row2" >2:high</th>
#       <td id="T_c318a_row2_col0" class="data row2 col0" >-0.30</td>
#       <td id="T_c318a_row2_col1" class="data row2 col1" >0.25</td>
#       <td id="T_c318a_row2_col2" class="data row2 col2" >-0.45</td>
#       <td id="T_c318a_row2_col3" class="data row2 col3" >0.15</td>
#       <td id="T_c318a_row2_col4" class="data row2 col4" >-0.45</td>
#       <td id="T_c318a_row2_col5" class="data row2 col5" >0.15</td>
#       <td id="T_c318a_row2_col6" class="data row2 col6" >-0.33</td>
#       <td id="T_c318a_row2_col7" class="data row2 col7" >0.16</td>
#       <td id="T_c318a_row2_col8" class="data row2 col8" >-0.27</td>
#       <td id="T_c318a_row2_col9" class="data row2 col9" >0.17</td>
#       <td id="T_c318a_row2_col10" class="data row2 col10" >-0.24</td>
#       <td id="T_c318a_row2_col11" cl

# %%
ports2_temp = filter_pscores(ports2).copy()
caption = ("One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals"
           " by F-Score <br> Bull and Bear markets"
          )
d = (
    pd.pivot_table(
    data=ports2_temp.query('return_type == "ma_ret"'),
    index=['return_type','group',], 
    columns=['market'], 
    aggfunc=['mean',p5,p10,p25,p50,p75,p90,pos,ES,MS], 
    values='value',
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)

display(d)
dfi.export(d,"bulls_bears_returns_pscore.png",max_cols=-1)
# Out:
# <style type="text/css">
# #T_56fb3 caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_56fb3 td {
#   font-family: Times New Roman;
# }
# #T_56fb3 th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_56fb3">
#   <caption>One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score <br> Bull and Bear markets</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56fb3_level0_col0" class="col_heading level0 col0" colspan="2">mean</th>
#       <th id="T_56fb3_level0_col2" class="col_heading level0 col2" colspan="2">p5</th>
#       <th id="T_56fb3_level0_col4" class="col_heading level0 col4" colspan="2">p10</th>
#       <th id="T_56fb3_level0_col6" class="col_heading level0 col6" colspan="2">p25</th>
#       <th id="T_56fb3_level0_col8" class="col_heading level0 col8" colspan="2">p50</th>
#       <th id="T_56fb3_level0_col10" class="col_heading level0 col10" colspan="2">p75</th>
#       <th id="T_56fb3_level0_col12" class="col_heading level0 col12" colspan="2">p90</th>
#       <th id="T_56fb3_level0_col14" class="col_heading level0 col14" colspan="2">pos</th>
#       <th id="T_56fb3_level0_col16" class="col_heading level0 col16" colspan="2">ES</th>
#       <th id="T_56fb3_level0_col18" class="col_heading level0 col18" colspan="2">MS</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >market</th>
#       <th id="T_56fb3_level1_col0" class="col_heading level1 col0" >bear</th>
#       <th id="T_56fb3_level1_col1" class="col_heading level1 col1" >bull</th>
#       <th id="T_56fb3_level1_col2" class="col_heading level1 col2" >bear</th>
#       <th id="T_56fb3_level1_col3" class="col_heading level1 col3" >bull</th>
#       <th id="T_56fb3_level1_col4" class="col_heading level1 col4" >bear</th>
#       <th id="T_56fb3_level1_col5" class="col_heading level1 col5" >bull</th>
#       <th id="T_56fb3_level1_col6" class="col_heading level1 col6" >bear</th>
#       <th id="T_56fb3_level1_col7" class="col_heading level1 col7" >bull</th>
#       <th id="T_56fb3_level1_col8" class="col_heading level1 col8" >bear</th>
#       <th id="T_56fb3_level1_col9" class="col_heading level1 col9" >bull</th>
#       <th id="T_56fb3_level1_col10" class="col_heading level1 col10" >bear</th>
#       <th id="T_56fb3_level1_col11" class="col_heading level1 col11" >bull</th>
#       <th id="T_56fb3_level1_col12" class="col_heading level1 col12" >bear</th>
#       <th id="T_56fb3_level1_col13" class="col_heading level1 col13" >bull</th>
#       <th id="T_56fb3_level1_col14" class="col_heading level1 col14" >bear</th>
#       <th id="T_56fb3_level1_col15" class="col_heading level1 col15" >bull</th>
#       <th id="T_56fb3_level1_col16" class="col_heading level1 col16" >bear</th>
#       <th id="T_56fb3_level1_col17" class="col_heading level1 col17" >bull</th>
#       <th id="T_56fb3_level1_col18" class="col_heading level1 col18" >bear</th>
#       <th id="T_56fb3_level1_col19" class="col_heading level1 col19" >bull</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >return_type</th>
#       <th class="index_name level1" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56fb3_level0_row0" class="row_heading level0 row0" rowspan="10">ma_ret</th>
#       <th id="T_56fb3_level1_row0" class="row_heading level1 row0" >p0</th>
#       <td id="T_56fb3_row0_col0" class="data row0 col0" >-0.26</td>
#       <td id="T_56fb3_row0_col1" class="data row0 col1" >-0.08</td>
#       <td id="T_56fb3_row0_col2" class="data row0 col2" >-0.43</td>
#       <td id="T_56fb3_row0_col3" class="data row0 col3" >-0.65</td>
#       <td id="T_56fb3_row0_col4" class="data row0 col4" >-0.43</td>
#       <td id="T_56fb3_row0_col5" class="data row0 col5" >-0.54</td>
#       <td id="T_56fb3_row0_col6" class="data row0 col6" >-0.43</td>
#       <td id="T_56fb3_row0_col7" class="data row0 col7" >-0.22</td>
#       <td id="T_56fb3_row0_col8" class="data row0 col8" >-0.22</td>
#       <td id="T_56fb3_row0_col9" class="data row0 col9" >-0.10</td>
#       <td id="T_56fb3_row0_col10" class="data row0 col10" >-0.12</td>
#       <td id="T_56fb3_row0_col11" class="data row0 col11" >0.12</td>
#       <td id="T_56fb3_row0_col12" class="data row0 col12" >-0.12</td>
#       <td id="T_56fb3_row0_col13" class="data row0 col13" >0.31</td>
#       <td id="T_56fb3_row0_col14" class="data row0 col14" >0.01</td>
#       <td id="T_56fb3_row0_col15" class="data row0 col15" >0.40</td>
#       <td id="T_56fb3_row0_col16" class="data row0 col16" >-0.44</td>
#       <td id="T_56fb3_row0_col17" class="data row0 col17" >-0.75</td>
#       <td id="T_56fb3_row0_col18" class="data row0 col18" >-0.43</td>
#       <td id="T_56fb3_row0_col19" class="data row0 col19" >-0.73</td>
#     </tr>
#     <tr>
#       <th id="T_56fb3_level1_row1" class="row_heading level1 row1" >p1</th>
#       <td id="T_56fb3_row1_col0" class="data row1 col0" >-0.16</td>
#       <td id="T_56fb3_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_56fb3_row1_col2" class="data row1 col2" >-0.37</td>
#       <td id="T_56fb3_row1_col3" class="data row1 col3" >-0.55</td>
#       <td id="T_56fb3_row1_col4" class="data row1 col4" >-0.34</td>
#       <td id="T_56fb3_row1_col5" class="data row1 col5" >-0.36</td>
#       <td id="T_56fb3_row1_col6" class="data row1 col6" >-0.34</td>
#       <td id="T_56fb3_row1_col7" class="data row1 col7" >-0.10</td>
#       <td id="T_56fb3_row1_col8" class="data row1 col8" >-0.09</td>
#       <td id="T_56fb3_row1_col9" class="data row1 col9" >-0.06</td>
#       <td id="T_56fb3_row1_col10" class="data row1 col10" >-0.04</td>
#       <td id="T_56fb3_row1_col11" class="data row1 col11" >0.19</td>
#       <td id="T_56fb3_row1_col12" class="data row1 col12" >0.01</td>
#       <td id="T_56fb3_row1_col13" class="data row1 col13" >0.22</td>
#       <td id="T_56fb3_row1_col14" class="data row1 col14" >0.13</td>
#       <td id="T_56fb3_row1_col15" class="data row1 col15" >0.37</td>
#       <td id="T_56fb3_row1_col16" class="data row1 col16" >-0.44</td>
#       <td id="T_56fb3_row1_col17" class="data row1 col17" >-0.69</td>
#       <td id="T_56fb3_row1_col18" class="data row1 col18" >-0.43</td>
#       <td id="T_56fb3_row1_col19" class="data row1 col19" >-0.67</td>
#     </tr>
#     <tr>
#       <th id="T_56fb3_level1_row2" class="row_heading level1 row2" >p2</th>
#       <td id="T_56fb3_row2_col0" class="data row2 col0" >0.03</td>
#       <td id="T_56fb3_row2_col1" class="data row2 col1" >0.15</td>
#       <td id="T_56fb3_row2_col2" class="data row2 col2" >-0.38</td>
#       <td id="T_56fb3_row2_col3" class="data row2 col3" >-0.57</td>
#       <td id="T_56fb3_row2_col4" class="data row2 col4" >-0.29</td>
#       <td id="T_56fb3_row2_col5" class="data row2 col5" >-0.36</td>
#       <td id="T_56fb3_row2_col6" class="data row2 col6" >-0.10</td>
#       <td id="T_56fb3_row2_col7" class="data row2 col7" >-0.07</td>
#       <td id="T_56fb3_row2_col8" class="data row2 col8" >-0.00</td>
#       <td id="T_56fb3_row2_col9" class="data row2 col9" >0.05</td>
#       <td id="T_56fb3_row2_col10" class="data row2 col10" >0.23</td>
#       <td id="T_56fb3_row2_col11" cla

# %%
sort_rule = {f'p{i}': i for i in range(10)}
sns.set(rc={'figure.figsize':(8.27, 5)})
p = sns.catplot(
    data=ports2[ports2.group.isin([f'p{i}' for i in range(10)])]
    .sort_values(by=['market'])
    .sort_values(by=['group'], key=lambda series: series.apply(lambda x: sort_rule[x])),
    y="value", hue='return_type', x='group',kind="box",
    showfliers = False,
    col='market',
    row='covid_era',
)
plt.show()

# %% [markdown]
# # VaR

# %%
pgroup = {
    "plo":"0:low",
    "pmid":"1:mid",
    "phi":"2:high"
}
ports2_temp = filter_pscore_groups(ports2).query('return_type == "ma_ret"').copy()
ports2_temp['group'] = ports2_temp.group.map(pgroup)

caption = "One-Year Raw Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score"
d = (pd.pivot_table(
        data=ports2_temp,
        columns=['market'],
        values=['value'],
        index=['group'], 
        aggfunc=['mean', p5, ES, MS], 
    )
    .reorder_levels([2, 1, 0], axis=1)
    .sort_index(axis=1)
    .droplevel(1, axis=1)
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)
display(d)
dfi.export(d,"bull_bear_var.png",max_cols=-1)
# Out:
# <style type="text/css">
# #T_27210 caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_27210 td {
#   font-family: Times New Roman;
# }
# #T_27210 th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_27210">
#   <caption>One-Year Raw Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >market</th>
#       <th id="T_27210_level0_col0" class="col_heading level0 col0" colspan="4">bear</th>
#       <th id="T_27210_level0_col4" class="col_heading level0 col4" colspan="4">bull</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_27210_level1_col0" class="col_heading level1 col0" >ES</th>
#       <th id="T_27210_level1_col1" class="col_heading level1 col1" >MS</th>
#       <th id="T_27210_level1_col2" class="col_heading level1 col2" >mean</th>
#       <th id="T_27210_level1_col3" class="col_heading level1 col3" >p5</th>
#       <th id="T_27210_level1_col4" class="col_heading level1 col4" >ES</th>
#       <th id="T_27210_level1_col5" class="col_heading level1 col5" >MS</th>
#       <th id="T_27210_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_27210_level1_col7" class="col_heading level1 col7" >p5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27210_level0_row0" class="row_heading level0 row0" >0:low</th>
#       <td id="T_27210_row0_col0" class="data row0 col0" >-0.43</td>
#       <td id="T_27210_row0_col1" class="data row0 col1" >-0.42</td>
#       <td id="T_27210_row0_col2" class="data row0 col2" >-0.16</td>
#       <td id="T_27210_row0_col3" class="data row0 col3" >-0.36</td>
#       <td id="T_27210_row0_col4" class="data row0 col4" >-0.70</td>
#       <td id="T_27210_row0_col5" class="data row0 col5" >-0.68</td>
#       <td id="T_27210_row0_col6" class="data row0 col6" >-0.03</td>
#       <td id="T_27210_row0_col7" class="data row0 col7" >-0.57</td>
#     </tr>
#     <tr>
#       <th id="T_27210_level0_row1" class="row_heading level0 row1" >1:mid</th>
#       <td id="T_27210_row1_col0" class="data row1 col0" >-0.21</td>
#       <td id="T_27210_row1_col1" class="data row1 col1" >-0.20</td>
#       <td id="T_27210_row1_col2" class="data row1 col2" >0.07</td>
#       <td id="T_27210_row1_col3" class="data row1 col3" >-0.16</td>
#       <td id="T_27210_row1_col4" class="data row1 col4" >-0.44</td>
#       <td id="T_27210_row1_col5" class="data row1 col5" >-0.42</td>
#       <td id="T_27210_row1_col6" class="data row1 col6" >0.10</td>
#       <td id="T_27210_row1_col7" class="data row1 col7" >-0.32</td>
#     </tr>
#     <tr>
#       <th id="T_27210_level0_row2" class="row_heading level0 row2" >2:high</th>
#       <td id="T_27210_row2_col0" class="data row2 col0" >-0.25</td>
#       <td id="T_27210_row2_col1" class="data row2 col1" >-0.24</td>
#       <td id="T_27210_row2_col2" class="data row2 col2" >0.09</td>
#       <td id="T_27210_row2_col3" class="data row2 col3" >-0.22</td>
#       <td id="T_27210_row2_col4" class="data row2 col4" >-0.08</td>
#       <td id="T_27210_row2_col5" class="data row2 col5" >-0.07</td>
#       <td id="T_27210_row2_col6" class="data row2 col6" >0.13</td>
#       <td id="T_27210_row2_col7" class="data row2 col7" >-0.07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Covid Era

# %%
caption = "One-Year Raw Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score"
d = (pd.pivot_table(
        data=ports[ports.group.isin(['market', 'all', 'phi', 'plo'])],
        columns=['market'],
        values=['raw_ret'],#, 'ma_ret'],
        index=['covid_era', 'group', ], 
        aggfunc=['mean', p5, p10, p25, p50, p75, p90, pos, ES, MS], 
        margins=True
    )
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)
display(d)
dfi.export(d,"port_covid_raw.png",max_cols=-1)
caption = "One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score"

d = (pd.pivot_table(
        data=ports[ports.group.isin(['market', 'all', 'phi', 'plo'])],
        columns=['market'],
        values=['ma_ret'],#, 'ma_ret'],
        index=['covid_era', 'group', ], 
        aggfunc=['mean', p5, p10, p25, p50, p75, p90, pos, ES, MS], 
        margins=True
    )
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)
display(d)

dfi.export(d,"port_covid_ma.png",max_cols=-1)
# Out:
# <style type="text/css">
# #T_dd99d caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_dd99d td {
#   font-family: Times New Roman;
# }
# #T_dd99d th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_dd99d">
#   <caption>One-Year Raw Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd99d_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#       <th id="T_dd99d_level0_col3" class="col_heading level0 col3" colspan="3">p5</th>
#       <th id="T_dd99d_level0_col6" class="col_heading level0 col6" colspan="3">p10</th>
#       <th id="T_dd99d_level0_col9" class="col_heading level0 col9" colspan="3">p25</th>
#       <th id="T_dd99d_level0_col12" class="col_heading level0 col12" colspan="3">p50</th>
#       <th id="T_dd99d_level0_col15" class="col_heading level0 col15" colspan="3">p75</th>
#       <th id="T_dd99d_level0_col18" class="col_heading level0 col18" colspan="3">p90</th>
#       <th id="T_dd99d_level0_col21" class="col_heading level0 col21" colspan="3">pos</th>
#       <th id="T_dd99d_level0_col24" class="col_heading level0 col24" colspan="3">ES</th>
#       <th id="T_dd99d_level0_col27" class="col_heading level0 col27" colspan="3">MS</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_dd99d_level1_col0" class="col_heading level1 col0" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col3" class="col_heading level1 col3" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col6" class="col_heading level1 col6" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col9" class="col_heading level1 col9" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col12" class="col_heading level1 col12" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col15" class="col_heading level1 col15" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col18" class="col_heading level1 col18" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col21" class="col_heading level1 col21" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col24" class="col_heading level1 col24" colspan="3">raw_ret</th>
#       <th id="T_dd99d_level1_col27" class="col_heading level1 col27" colspan="3">raw_ret</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >market</th>
#       <th id="T_dd99d_level2_col0" class="col_heading level2 col0" >bear</th>
#       <th id="T_dd99d_level2_col1" class="col_heading level2 col1" >bull</th>
#       <th id="T_dd99d_level2_col2" class="col_heading level2 col2" >All</th>
#       <th id="T_dd99d_level2_col3" class="col_heading level2 col3" >bear</th>
#       <th id="T_dd99d_level2_col4" class="col_heading level2 col4" >bull</th>
#       <th id="T_dd99d_level2_col5" class="col_heading level2 col5" >All</th>
#       <th id="T_dd99d_level2_col6" class="col_heading level2 col6" >bear</th>
#       <th id="T_dd99d_level2_col7" class="col_heading level2 col7" >bull</th>
#       <th id="T_dd99d_level2_col8" class="col_heading level2 col8" >All</th>
#       <th id="T_dd99d_level2_col9" class="col_heading level2 col9" >bear</th>
#       <th id="T_dd99d_level2_col10" class="col_heading level2 col10" >bull</th>
#       <th id="T_dd99d_level2_col11" class="col_heading level2 col11" >All</th>
#       <th id="T_dd99d_level2_col12" class="col_heading level2 col12" >bear</th>
#       <th id="T_dd99d_level2_col13" class="col_heading level2 col13" >bull</th>
#       <th id="T_dd99d_level2_col14" class="col_heading level2 col14" >All</th>
#       <th id="T_dd99d_level2_col15" class="col_heading level2 col15" >bear</th>
#       <th id="T_dd99d_level2_col16" class="col_heading level2 col16" >bull</th>
#       <th id="T_dd99d_level2_col17" class="col_heading level2 col17" >All</th>
#       <th id="T_dd99d_level2_col18" class="col_heading level2 col18" >bear</th>
#       <th id="T_dd99d_level2_col19" class="col_heading level2 col19" >bull</th>
#       <th id="T_dd99d_level2_col20" class="col_heading level2 col20" >All</th>
#       <th id="T_dd99d_level2_col21" class="col_heading level2 col21" >bear</th>
#       <th id="T_dd99d_level2_col22" class="col_heading level2 col22" >bull</th>
#       <th id="T_dd99d_level2_col23" class="col_heading level2 col23" >All</th>
#       <th id="T_dd99d_level2_col24" class="col_heading level2 col24" >bear</th>
#       <th id="T_dd99d_level2_col25" class="col_heading level2 col25" >bull</th>
#       <th id="T_dd99d_level2_col26" class="col_heading level2 col26" >All</th>
#       <th id="T_dd99d_level2_col27" class="col_heading level2 col27" >bear</th>
#       <th id="T_dd99d_level2_col28" class="col_heading level2 col28" >bull</th>
#       <th id="T_dd99d_level2_col29" class="col_heading level2 col29" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >covid_era</th>
#       <th class="index_name level1" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd99d_level0_row0" class="row_heading level0 row0" rowspan="4">False</th>
#       <th id="T_dd99d_level1_row0" class="row_heading level1 row0" >all</th>
#       <td id="T_dd99d_row0_col0" class="data row0 col0" >-0.20</td>
#       <td id="T_dd99d_row0_col1" class="data row0 col1" >0.19</td>
#       <td id="T_dd99d_row0_col2" class="data row0 col2" >0.03</td>
#       <td id="T_dd99d_row0_col3" class="data row0 col3" >-0.53</td>
#       <td id="T_dd99d_row0_col4" class="data row0 col4" >0.08</td>
#       <td id="T_dd99d_row0_col5" class="data row0 col5" >-0.48</td>
#       <td id="T_dd99d_row0_col6" class="data row0 col6" >-0.49</td>
#       <td id="T_dd99d_row0_col7" class="data row0 col7" >0.08</td>
#       <td id="T_dd99d_row0_col8" class="data row0 col8" >-0.41</td>
#       <td id="T_dd99d_row0_col9" class="data row0 col9" >-0.40</td>
#       <td id="T_dd99d_row0_col10" class="data row0 col10" >0.08</td>
#       <td id="T_dd99d_row0_col11" class="data row0 col11" >-0.24</td>
#       <td id="T_dd99d_row0_col12" class="data row0 col12" >-0.24</td>
#       <td id="T_dd99d_row0_col13" class="data row0 col13" >0.21</td>
#       <td id="T_dd99d_row0_col14" class="data row0 col14" >0.08</td>
#       <td id="T_dd99d_row0_col15" class="data row0 col15" >0.04</td>
#       <td id="T_dd99d_row0_col16" class="data row0 col16" >0.24</td>
#       <td id="T_dd99d_row0_col17" class="data row0 col17" >0.24</td>
#       <td id="T_dd99d_row0_col18" class="data row0 col18" >0.13</td>
#       <td id="T_dd99d_row0_col19" class="data row0 col19" >0.31</td>
#       <td id="T_dd99d_row0_col20" class="data row0 col20" >0.26</td>
#       <td id="T_dd99d_row0_col21" class="data row0 col21" >0.29</td>
# <style type="text/css">
# #T_ad779 caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_ad779 td {
#   font-family: Times New Roman;
# }
# #T_ad779 th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_ad779">
#   <caption>One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad779_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#       <th id="T_ad779_level0_col3" class="col_heading level0 col3" colspan="3">p5</th>
#       <th id="T_ad779_level0_col6" class="col_heading level0 col6" colspan="3">p10</th>
#       <th id="T_ad779_level0_col9" class="col_heading level0 col9" colspan="3">p25</th>
#       <th id="T_ad779_level0_col12" class="col_heading level0 col12" colspan="3">p50</th>
#       <th id="T_ad779_level0_col15" class="col_heading level0 col15" colspan="3">p75</th>
#       <th id="T_ad779_level0_col18" class="col_heading level0 col18" colspan="3">p90</th>
#       <th id="T_ad779_level0_col21" class="col_heading level0 col21" colspan="3">pos</th>
#       <th id="T_ad779_level0_col24" class="col_heading level0 col24" colspan="3">ES</th>
#       <th id="T_ad779_level0_col27" class="col_heading level0 col27" colspan="3">MS</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_ad779_level1_col0" class="col_heading level1 col0" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col3" class="col_heading level1 col3" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col6" class="col_heading level1 col6" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col9" class="col_heading level1 col9" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col12" class="col_heading level1 col12" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col15" class="col_heading level1 col15" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col18" class="col_heading level1 col18" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col21" class="col_heading level1 col21" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col24" class="col_heading level1 col24" colspan="3">ma_ret</th>
#       <th id="T_ad779_level1_col27" class="col_heading level1 col27" colspan="3">ma_ret</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >market</th>
#       <th id="T_ad779_level2_col0" class="col_heading level2 col0" >bear</th>
#       <th id="T_ad779_level2_col1" class="col_heading level2 col1" >bull</th>
#       <th id="T_ad779_level2_col2" class="col_heading level2 col2" >All</th>
#       <th id="T_ad779_level2_col3" class="col_heading level2 col3" >bear</th>
#       <th id="T_ad779_level2_col4" class="col_heading level2 col4" >bull</th>
#       <th id="T_ad779_level2_col5" class="col_heading level2 col5" >All</th>
#       <th id="T_ad779_level2_col6" class="col_heading level2 col6" >bear</th>
#       <th id="T_ad779_level2_col7" class="col_heading level2 col7" >bull</th>
#       <th id="T_ad779_level2_col8" class="col_heading level2 col8" >All</th>
#       <th id="T_ad779_level2_col9" class="col_heading level2 col9" >bear</th>
#       <th id="T_ad779_level2_col10" class="col_heading level2 col10" >bull</th>
#       <th id="T_ad779_level2_col11" class="col_heading level2 col11" >All</th>
#       <th id="T_ad779_level2_col12" class="col_heading level2 col12" >bear</th>
#       <th id="T_ad779_level2_col13" class="col_heading level2 col13" >bull</th>
#       <th id="T_ad779_level2_col14" class="col_heading level2 col14" >All</th>
#       <th id="T_ad779_level2_col15" class="col_heading level2 col15" >bear</th>
#       <th id="T_ad779_level2_col16" class="col_heading level2 col16" >bull</th>
#       <th id="T_ad779_level2_col17" class="col_heading level2 col17" >All</th>
#       <th id="T_ad779_level2_col18" class="col_heading level2 col18" >bear</th>
#       <th id="T_ad779_level2_col19" class="col_heading level2 col19" >bull</th>
#       <th id="T_ad779_level2_col20" class="col_heading level2 col20" >All</th>
#       <th id="T_ad779_level2_col21" class="col_heading level2 col21" >bear</th>
#       <th id="T_ad779_level2_col22" class="col_heading level2 col22" >bull</th>
#       <th id="T_ad779_level2_col23" class="col_heading level2 col23" >All</th>
#       <th id="T_ad779_level2_col24" class="col_heading level2 col24" >bear</th>
#       <th id="T_ad779_level2_col25" class="col_heading level2 col25" >bull</th>
#       <th id="T_ad779_level2_col26" class="col_heading level2 col26" >All</th>
#       <th id="T_ad779_level2_col27" class="col_heading level2 col27" >bear</th>
#       <th id="T_ad779_level2_col28" class="col_heading level2 col28" >bull</th>
#       <th id="T_ad779_level2_col29" class="col_heading level2 col29" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >covid_era</th>
#       <th class="index_name level1" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad779_level0_row0" class="row_heading level0 row0" rowspan="4">False</th>
#       <th id="T_ad779_level1_row0" class="row_heading level1 row0" >all</th>
#       <td id="T_ad779_row0_col0" class="data row0 col0" >0.13</td>
#       <td id="T_ad779_row0_col1" class="data row0 col1" >0.01</td>
#       <td id="T_ad779_row0_col2" class="data row0 col2" >0.06</td>
#       <td id="T_ad779_row0_col3" class="data row0 col3" >-0.08</td>
#       <td id="T_ad779_row0_col4" class="data row0 col4" >-0.09</td>
#       <td id="T_ad779_row0_col5" class="data row0 col5" >-0.09</td>
#       <td id="T_ad779_row0_col6" class="data row0 col6" >-0.05</td>
#       <td id="T_ad779_row0_col7" class="data row0 col7" >-0.09</td>
#       <td id="T_ad779_row0_col8" class="data row0 col8" >-0.09</td>
#       <td id="T_ad779_row0_col9" class="data row0 col9" >0.05</td>
#       <td id="T_ad779_row0_col10" class="data row0 col10" >-0.09</td>
#       <td id="T_ad779_row0_col11" class="data row0 col11" >-0.02</td>
#       <td id="T_ad779_row0_col12" class="data row0 col12" >0.06</td>
#       <td id="T_ad779_row0_col13" class="data row0 col13" >-0.02</td>
#       <td id="T_ad779_row0_col14" class="data row0 col14" >0.03</td>
#       <td id="T_ad779_row0_col15" class="data row0 col15" >0.27</td>
#       <td id="T_ad779_row0_col16" class="data row0 col16" >0.06</td>
#       <td id="T_ad779_row0_col17" class="data row0 col17" >0.11</td>
#       <td id="T_ad779_row0_col18" class="data row0 col18" >0.37</td>
#       <td id="T_ad779_row0_col19" class="data row0 col19" >0.16</td>
#       <td id="T_ad779_row0_col20" class="data row0 col20" >0.29</td>
#       <td id="T_ad779_row0_col21" class="data row0 col21" >0.83</td>

# %% [markdown]
# # Alternate Partitions
# ### In the below section, instead of creating portfolios of stocks, I look at returns from each separate firm. Then I aggregate over the results. These are not portfolio returns.

# %%
indiv = augment_individual_stock_bull_bear(highbm, bulls, bears)
# reshape so returns are in separate rows for seaborn
indiv['covid_era'] = pd.to_datetime(indiv.start) > pd.to_datetime('2018-01-01')
indiv2 = pd.melt(indiv, id_vars=['start', 'end', 'market', 'pscore', 'symbol', 'mve_quintile', 'price_quintile', 'pscore_group', 'covid_era'], value_vars=['raw_ret', 'ma_ret', 'm_ret'], var_name='return_type')

# %% [markdown]
# # Partitioned by Market Value of Equity

# %%
caption = ("One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-score <br>"
           "Partitioned by Market Value of Equity")
d = (pd.pivot_table(
    data=indiv2.query('return_type == "ma_ret"'), 
    index=['market', 'pscore_group',], 
    columns=['mve_quintile'], 
    aggfunc=['mean', p10, p25, p50, p75, p90, pos, ], 
    values='value',
#         margins=True
    )
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)
display(d)
dfi.export(d,"bulls_bears_ma_mve.png",max_cols=-1)
# Out:
# <style type="text/css">
# #T_a5cf1 caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_a5cf1 td {
#   font-family: Times New Roman;
# }
# #T_a5cf1 th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_a5cf1">
#   <caption>One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-score <br>Partitioned by Market Value of Equity</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5cf1_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#       <th id="T_a5cf1_level0_col3" class="col_heading level0 col3" colspan="3">p10</th>
#       <th id="T_a5cf1_level0_col6" class="col_heading level0 col6" colspan="3">p25</th>
#       <th id="T_a5cf1_level0_col9" class="col_heading level0 col9" colspan="3">p50</th>
#       <th id="T_a5cf1_level0_col12" class="col_heading level0 col12" colspan="3">p75</th>
#       <th id="T_a5cf1_level0_col15" class="col_heading level0 col15" colspan="3">p90</th>
#       <th id="T_a5cf1_level0_col18" class="col_heading level0 col18" colspan="3">pos</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >mve_quintile</th>
#       <th id="T_a5cf1_level1_col0" class="col_heading level1 col0" >0:low</th>
#       <th id="T_a5cf1_level1_col1" class="col_heading level1 col1" >1:med</th>
#       <th id="T_a5cf1_level1_col2" class="col_heading level1 col2" >2:high</th>
#       <th id="T_a5cf1_level1_col3" class="col_heading level1 col3" >0:low</th>
#       <th id="T_a5cf1_level1_col4" class="col_heading level1 col4" >1:med</th>
#       <th id="T_a5cf1_level1_col5" class="col_heading level1 col5" >2:high</th>
#       <th id="T_a5cf1_level1_col6" class="col_heading level1 col6" >0:low</th>
#       <th id="T_a5cf1_level1_col7" class="col_heading level1 col7" >1:med</th>
#       <th id="T_a5cf1_level1_col8" class="col_heading level1 col8" >2:high</th>
#       <th id="T_a5cf1_level1_col9" class="col_heading level1 col9" >0:low</th>
#       <th id="T_a5cf1_level1_col10" class="col_heading level1 col10" >1:med</th>
#       <th id="T_a5cf1_level1_col11" class="col_heading level1 col11" >2:high</th>
#       <th id="T_a5cf1_level1_col12" class="col_heading level1 col12" >0:low</th>
#       <th id="T_a5cf1_level1_col13" class="col_heading level1 col13" >1:med</th>
#       <th id="T_a5cf1_level1_col14" class="col_heading level1 col14" >2:high</th>
#       <th id="T_a5cf1_level1_col15" class="col_heading level1 col15" >0:low</th>
#       <th id="T_a5cf1_level1_col16" class="col_heading level1 col16" >1:med</th>
#       <th id="T_a5cf1_level1_col17" class="col_heading level1 col17" >2:high</th>
#       <th id="T_a5cf1_level1_col18" class="col_heading level1 col18" >0:low</th>
#       <th id="T_a5cf1_level1_col19" class="col_heading level1 col19" >1:med</th>
#       <th id="T_a5cf1_level1_col20" class="col_heading level1 col20" >2:high</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >market</th>
#       <th class="index_name level1" >pscore_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5cf1_level0_row0" class="row_heading level0 row0" rowspan="3">bear</th>
#       <th id="T_a5cf1_level1_row0" class="row_heading level1 row0" >0-1:lo</th>
#       <td id="T_a5cf1_row0_col0" class="data row0 col0" >-0.23</td>
#       <td id="T_a5cf1_row0_col1" class="data row0 col1" >-0.07</td>
#       <td id="T_a5cf1_row0_col2" class="data row0 col2" >0.02</td>
#       <td id="T_a5cf1_row0_col3" class="data row0 col3" >-0.69</td>
#       <td id="T_a5cf1_row0_col4" class="data row0 col4" >-0.40</td>
#       <td id="T_a5cf1_row0_col5" class="data row0 col5" >-0.18</td>
#       <td id="T_a5cf1_row0_col6" class="data row0 col6" >-0.64</td>
#       <td id="T_a5cf1_row0_col7" class="data row0 col7" >-0.23</td>
#       <td id="T_a5cf1_row0_col8" class="data row0 col8" >0.01</td>
#       <td id="T_a5cf1_row0_col9" class="data row0 col9" >-0.34</td>
#       <td id="T_a5cf1_row0_col10" class="data row0 col10" >-0.06</td>
#       <td id="T_a5cf1_row0_col11" class="data row0 col11" >0.03</td>
#       <td id="T_a5cf1_row0_col12" class="data row0 col12" >0.24</td>
#       <td id="T_a5cf1_row0_col13" class="data row0 col13" >0.14</td>
#       <td id="T_a5cf1_row0_col14" class="data row0 col14" >0.04</td>
#       <td id="T_a5cf1_row0_col15" class="data row0 col15" >0.27</td>
#       <td id="T_a5cf1_row0_col16" class="data row0 col16" >0.21</td>
#       <td id="T_a5cf1_row0_col17" class="data row0 col17" >0.16</td>
#       <td id="T_a5cf1_row0_col18" class="data row0 col18" >0.37</td>
#       <td id="T_a5cf1_row0_col19" class="data row0 col19" >0.33</td>
#       <td id="T_a5cf1_row0_col20" class="data row0 col20" >0.78</td>
#     </tr>
#     <tr>
#       <th id="T_a5cf1_level1_row1" class="row_heading level1 row1" >2-7:med</th>
#       <td id="T_a5cf1_row1_col0" class="data row1 col0" >0.01</td>
#       <td id="T_a5cf1_row1_col1" class="data row1 col1" >0.05</td>
#       <td id="T_a5cf1_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_a5cf1_row1_col3" class="data row1 col3" >-0.51</td>
#       <td id="T_a5cf1_row1_col4" class="data row1 col4" >-0.33</td>
#       <td id="T_a5cf1_row1_col5" class="data row1 col5" >-0.26</td>
#       <td id="T_a5cf1_row1_col6" class="data row1 col6" >-0.28</td>
#       <td id="T_a5cf1_row1_col7" class="data row1 col7" >-0.15</td>
#       <td id="T_a5cf1_row1_col8" class="data row1 col8" >-0.11</td>
#       <td id="T_a5cf1_row1_col9" class="data row1 col9" >-0.05</td>
#       <td id="T_a5cf1_row1_col10" class="data row1 col10" >-0.00</td>
#       <td id="T_a5cf1_row1_col11" class="data row1 col11" >0.03</td>
#       <td id="T_a5cf1_row1_col12" class="data row1 col12" >0.17</td>
#       <td id="T_a5cf1_row1_col13" class="data row1 col13" >0.22</td>
#       <td id="T_a5cf1_row1_col14" class="data row1 col14" >0.14</td>
#       <td id="T_a5cf1_row1_col15" class="data row1 col15" >0.42</td>
#       <td id="T_a5cf1_row1_col16" class="data row1 col16" >0.41</td>
#       <td id="T_a5cf1_row1_col17" class="data row1 col17" >0.26</td>
#       <td id="T_a5cf1_row1_col18" class="data row1 col18" >0.44</td>
#       <td id="T_a5cf1_row1_col19" class="data row1 col19" >0.50</td>
#       <td id="T_a5cf1_row1_col20" class="data row1 col20" >0.54</td>
#     </tr>
#     <tr>
#       <th id="T_a5cf1_level1_row2" class="row_heading level1 row2" >8-9:hi</th>
#       <td id="T_a5cf1_row2_col0" class="data row2 col0" >0.06</td>
#       <td id="T_a5cf1_row2_col1" class="data row2 col1" >0.05</td>
#       <td id="T_a5cf1_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_a5cf1_row2_col3" class="data row2 col3" >-0.33</td>
#       <td id="T_a5cf1_row2_col4" class="data row2 col4" >-0.28</td>
#       <td id="T_a5cf1_row2_col5" class="data row2 col5" >-0.30</td>
#       <td id="T_a5cf1_row2_col6" class="data row2 col6" >-0.20</td>
#       <td id="T_a5cf1_row2_col7" class="data row2 col7" >-0.18</td>
#       <td id="T_a5cf1_row2_col8" class="data row2 col8" >-0.08</td>
#       <td id="T_a5cf1_row2_col9" class="data row2 col9" >-0.02</td>
#       <td id="T_a5cf1_row2_col10" class="data row2 col10" >0.0

# %% [markdown]
# # Partitioned by Price

# %%
caption = ("One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-score <br>"
           "Partitioned by Share Price")
d = (
    pd.pivot_table(
    data=indiv2.query('return_type == "ma_ret"'), 
    index=['market', 'pscore_group',], 
    columns=['price_quintile'], 
    aggfunc=['mean', p10, p25, p50, p75, p90, pos, ], 
    values='value',
#         margins=True
    )
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)

display(d)
dfi.export(d,"bulls_bears_ma_price.png",max_cols=-1)
# Out:
# <style type="text/css">
# #T_96da6 caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_96da6 td {
#   font-family: Times New Roman;
# }
# #T_96da6 th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_96da6">
#   <caption>One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-score <br>Partitioned by Share Price</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96da6_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#       <th id="T_96da6_level0_col3" class="col_heading level0 col3" colspan="3">p10</th>
#       <th id="T_96da6_level0_col6" class="col_heading level0 col6" colspan="3">p25</th>
#       <th id="T_96da6_level0_col9" class="col_heading level0 col9" colspan="3">p50</th>
#       <th id="T_96da6_level0_col12" class="col_heading level0 col12" colspan="3">p75</th>
#       <th id="T_96da6_level0_col15" class="col_heading level0 col15" colspan="3">p90</th>
#       <th id="T_96da6_level0_col18" class="col_heading level0 col18" colspan="3">pos</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >price_quintile</th>
#       <th id="T_96da6_level1_col0" class="col_heading level1 col0" >0:small</th>
#       <th id="T_96da6_level1_col1" class="col_heading level1 col1" >1:med</th>
#       <th id="T_96da6_level1_col2" class="col_heading level1 col2" >2:large</th>
#       <th id="T_96da6_level1_col3" class="col_heading level1 col3" >0:small</th>
#       <th id="T_96da6_level1_col4" class="col_heading level1 col4" >1:med</th>
#       <th id="T_96da6_level1_col5" class="col_heading level1 col5" >2:large</th>
#       <th id="T_96da6_level1_col6" class="col_heading level1 col6" >0:small</th>
#       <th id="T_96da6_level1_col7" class="col_heading level1 col7" >1:med</th>
#       <th id="T_96da6_level1_col8" class="col_heading level1 col8" >2:large</th>
#       <th id="T_96da6_level1_col9" class="col_heading level1 col9" >0:small</th>
#       <th id="T_96da6_level1_col10" class="col_heading level1 col10" >1:med</th>
#       <th id="T_96da6_level1_col11" class="col_heading level1 col11" >2:large</th>
#       <th id="T_96da6_level1_col12" class="col_heading level1 col12" >0:small</th>
#       <th id="T_96da6_level1_col13" class="col_heading level1 col13" >1:med</th>
#       <th id="T_96da6_level1_col14" class="col_heading level1 col14" >2:large</th>
#       <th id="T_96da6_level1_col15" class="col_heading level1 col15" >0:small</th>
#       <th id="T_96da6_level1_col16" class="col_heading level1 col16" >1:med</th>
#       <th id="T_96da6_level1_col17" class="col_heading level1 col17" >2:large</th>
#       <th id="T_96da6_level1_col18" class="col_heading level1 col18" >0:small</th>
#       <th id="T_96da6_level1_col19" class="col_heading level1 col19" >1:med</th>
#       <th id="T_96da6_level1_col20" class="col_heading level1 col20" >2:large</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >market</th>
#       <th class="index_name level1" >pscore_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96da6_level0_row0" class="row_heading level0 row0" rowspan="3">bear</th>
#       <th id="T_96da6_level1_row0" class="row_heading level1 row0" >0-1:lo</th>
#       <td id="T_96da6_row0_col0" class="data row0 col0" >-0.30</td>
#       <td id="T_96da6_row0_col1" class="data row0 col1" >0.10</td>
#       <td id="T_96da6_row0_col2" class="data row0 col2" >-0.28</td>
#       <td id="T_96da6_row0_col3" class="data row0 col3" >-0.70</td>
#       <td id="T_96da6_row0_col4" class="data row0 col4" >-0.26</td>
#       <td id="T_96da6_row0_col5" class="data row0 col5" >-0.51</td>
#       <td id="T_96da6_row0_col6" class="data row0 col6" >-0.66</td>
#       <td id="T_96da6_row0_col7" class="data row0 col7" >0.01</td>
#       <td id="T_96da6_row0_col8" class="data row0 col8" >-0.44</td>
#       <td id="T_96da6_row0_col9" class="data row0 col9" >-0.54</td>
#       <td id="T_96da6_row0_col10" class="data row0 col10" >0.23</td>
#       <td id="T_96da6_row0_col11" class="data row0 col11" >-0.39</td>
#       <td id="T_96da6_row0_col12" class="data row0 col12" >0.23</td>
#       <td id="T_96da6_row0_col13" class="data row0 col13" >0.24</td>
#       <td id="T_96da6_row0_col14" class="data row0 col14" >-0.06</td>
#       <td id="T_96da6_row0_col15" class="data row0 col15" >0.27</td>
#       <td id="T_96da6_row0_col16" class="data row0 col16" >0.25</td>
#       <td id="T_96da6_row0_col17" class="data row0 col17" >0.01</td>
#       <td id="T_96da6_row0_col18" class="data row0 col18" >0.28</td>
#       <td id="T_96da6_row0_col19" class="data row0 col19" >0.78</td>
#       <td id="T_96da6_row0_col20" class="data row0 col20" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_96da6_level1_row1" class="row_heading level1 row1" >2-7:med</th>
#       <td id="T_96da6_row1_col0" class="data row1 col0" >0.03</td>
#       <td id="T_96da6_row1_col1" class="data row1 col1" >0.04</td>
#       <td id="T_96da6_row1_col2" class="data row1 col2" >-0.05</td>
#       <td id="T_96da6_row1_col3" class="data row1 col3" >-0.46</td>
#       <td id="T_96da6_row1_col4" class="data row1 col4" >-0.30</td>
#       <td id="T_96da6_row1_col5" class="data row1 col5" >-0.43</td>
#       <td id="T_96da6_row1_col6" class="data row1 col6" >-0.24</td>
#       <td id="T_96da6_row1_col7" class="data row1 col7" >-0.12</td>
#       <td id="T_96da6_row1_col8" class="data row1 col8" >-0.25</td>
#       <td id="T_96da6_row1_col9" class="data row1 col9" >-0.04</td>
#       <td id="T_96da6_row1_col10" class="data row1 col10" >0.02</td>
#       <td id="T_96da6_row1_col11" class="data row1 col11" >-0.03</td>
#       <td id="T_96da6_row1_col12" class="data row1 col12" >0.19</td>
#       <td id="T_96da6_row1_col13" class="data row1 col13" >0.17</td>
#       <td id="T_96da6_row1_col14" class="data row1 col14" >0.09</td>
#       <td id="T_96da6_row1_col15" class="data row1 col15" >0.46</td>
#       <td id="T_96da6_row1_col16" class="data row1 col16" >0.34</td>
#       <td id="T_96da6_row1_col17" class="data row1 col17" >0.25</td>
#       <td id="T_96da6_row1_col18" class="data row1 col18" >0.44</td>
#       <td id="T_96da6_row1_col19" class="data row1 col19" >0.55</td>
#       <td id="T_96da6_row1_col20" class="data row1 col20" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_96da6_level1_row2" class="row_heading level1 row2" >8-9:hi</th>
#       <td id="T_96da6_row2_col0" class="data row2 col0" >0.08</td>
#       <td id="T_96da6_row2_col1" class="data row2 col1" >0.06</td>
#       <td id="T_96da6_row2_col2" class="data row2 col2" >0.07</td>
#       <td id="T_96da6_row2_col3" class="data row2 col3" >-0.31</td>
#       <td id="T_96da6_row2_col4" class="data row2 col4" >-0.22</td>
#       <td id="T_96da6_row2_col5" class="data row2 col5" >-0.36</td>
#       <td id="T_96da6_row2_col6" class="data row2 col6" >-0.19</td>
#       <td id="T_96da6_row2_col7" class="data row2 col7" >-0.09</td>
#       <td id="T_96da6_row2_col8" class="data row2 col8" >-0.18</td>
#       <td id="T_96da6_row2_col9" class="data row2 col9" >-0.03</td>
#       <td id="T_96da6_row2_col10" class="data ro

# %%
sns.set(rc={'figure.figsize':(8.27, 5)})
indiv_temp = indiv2.query('return_type == "ma_ret"').sort_values(by=['pscore_group']).copy()
p = sns.catplot(
    data = indiv_temp,
    y="value", hue='pscore_group', x='price_quintile',kind="box",
    row='return_type',
    col='market',
    showfliers = False,
)

plt.show()
p.savefig("bulls_bears_ma_price_box.png")

# %%
sns.set(rc={'figure.figsize':(8.27, 5)})

p = sns.catplot(
    indiv2.sort_values(by=['mve_quintile']), y="value", hue='market', x='mve_quintile',kind="box",
    col='return_type',
    row='pscore',
    showfliers = False,
)
plt.show()

# %%
sns.set(rc={'figure.figsize':(8.27, 5)})

p = sns.catplot(
    indiv2.sort_values(by=['mve_quintile']), y="value", hue='return_type', x='mve_quintile',kind="box",
    log_scale=False,
    showfliers = False,
col='market'
)
plt.show()

# %%
caption = "One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score"
display(
    pd.pivot_table(
    data=indiv2, 
    index=['return_type','pscore',], 
    columns=['market'], 
    aggfunc=['mean', p5, p10, p25, p50, p75, p90, pos, ES, MS], 
    values='value',
    )
    .style
    .set_caption(caption)
    .set_table_styles(styles).format('{:.2f}')
)
# Out:
# <style type="text/css">
# #T_18779 caption {
#   font-family: Times New Roman;
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_18779 td {
#   font-family: Times New Roman;
# }
# #T_18779 th {
#   font-family: Times New Roman;
# }
# </style>
# <table id="T_18779">
#   <caption>One-Year Market-Adjusted Buy-and-Hold Returns to a Value Investment Strategy Based on Fundamental Signals by F-Score</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18779_level0_col0" class="col_heading level0 col0" colspan="2">mean</th>
#       <th id="T_18779_level0_col2" class="col_heading level0 col2" colspan="2">p5</th>
#       <th id="T_18779_level0_col4" class="col_heading level0 col4" colspan="2">p10</th>
#       <th id="T_18779_level0_col6" class="col_heading level0 col6" colspan="2">p25</th>
#       <th id="T_18779_level0_col8" class="col_heading level0 col8" colspan="2">p50</th>
#       <th id="T_18779_level0_col10" class="col_heading level0 col10" colspan="2">p75</th>
#       <th id="T_18779_level0_col12" class="col_heading level0 col12" colspan="2">p90</th>
#       <th id="T_18779_level0_col14" class="col_heading level0 col14" colspan="2">pos</th>
#       <th id="T_18779_level0_col16" class="col_heading level0 col16" colspan="2">ES</th>
#       <th id="T_18779_level0_col18" class="col_heading level0 col18" colspan="2">MS</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >market</th>
#       <th id="T_18779_level1_col0" class="col_heading level1 col0" >bear</th>
#       <th id="T_18779_level1_col1" class="col_heading level1 col1" >bull</th>
#       <th id="T_18779_level1_col2" class="col_heading level1 col2" >bear</th>
#       <th id="T_18779_level1_col3" class="col_heading level1 col3" >bull</th>
#       <th id="T_18779_level1_col4" class="col_heading level1 col4" >bear</th>
#       <th id="T_18779_level1_col5" class="col_heading level1 col5" >bull</th>
#       <th id="T_18779_level1_col6" class="col_heading level1 col6" >bear</th>
#       <th id="T_18779_level1_col7" class="col_heading level1 col7" >bull</th>
#       <th id="T_18779_level1_col8" class="col_heading level1 col8" >bear</th>
#       <th id="T_18779_level1_col9" class="col_heading level1 col9" >bull</th>
#       <th id="T_18779_level1_col10" class="col_heading level1 col10" >bear</th>
#       <th id="T_18779_level1_col11" class="col_heading level1 col11" >bull</th>
#       <th id="T_18779_level1_col12" class="col_heading level1 col12" >bear</th>
#       <th id="T_18779_level1_col13" class="col_heading level1 col13" >bull</th>
#       <th id="T_18779_level1_col14" class="col_heading level1 col14" >bear</th>
#       <th id="T_18779_level1_col15" class="col_heading level1 col15" >bull</th>
#       <th id="T_18779_level1_col16" class="col_heading level1 col16" >bear</th>
#       <th id="T_18779_level1_col17" class="col_heading level1 col17" >bull</th>
#       <th id="T_18779_level1_col18" class="col_heading level1 col18" >bear</th>
#       <th id="T_18779_level1_col19" class="col_heading level1 col19" >bull</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >return_type</th>
#       <th class="index_name level1" >pscore</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18779_level0_row0" class="row_heading level0 row0" rowspan="10">m_ret</th>
#       <th id="T_18779_level1_row0" class="row_heading level1 row0" >0.000000</th>
#       <td id="T_18779_row0_col0" class="data row0 col0" >-0.25</td>
#       <td id="T_18779_row0_col1" class="data row0 col1" >0.27</td>
#       <td id="T_18779_row0_col2" class="data row0 col2" >-0.25</td>
#       <td id="T_18779_row0_col3" class="data row0 col3" >0.27</td>
#       <td id="T_18779_row0_col4" class="data row0 col4" >-0.25</td>
#       <td id="T_18779_row0_col5" class="data row0 col5" >0.27</td>
#       <td id="T_18779_row0_col6" class="data row0 col6" >-0.25</td>
#       <td id="T_18779_row0_col7" class="data row0 col7" >0.27</td>
#       <td id="T_18779_row0_col8" class="data row0 col8" >-0.25</td>
#       <td id="T_18779_row0_col9" class="data row0 col9" >0.27</td>
#       <td id="T_18779_row0_col10" class="data row0 col10" >-0.25</td>
#       <td id="T_18779_row0_col11" class="data row0 col11" >0.27</td>
#       <td id="T_18779_row0_col12" class="data row0 col12" >-0.25</td>
#       <td id="T_18779_row0_col13" class="data row0 col13" >0.27</td>
#       <td id="T_18779_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_18779_row0_col15" class="data row0 col15" >1.00</td>
#       <td id="T_18779_row0_col16" class="data row0 col16" >-0.31</td>
#       <td id="T_18779_row0_col17" class="data row0 col17" >0.26</td>
#       <td id="T_18779_row0_col18" class="data row0 col18" >-0.29</td>
#       <td id="T_18779_row0_col19" class="data row0 col19" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_18779_level1_row1" class="row_heading level1 row1" >1.000000</th>
#       <td id="T_18779_row1_col0" class="data row1 col0" >-0.26</td>
#       <td id="T_18779_row1_col1" class="data row1 col1" >0.30</td>
#       <td id="T_18779_row1_col2" class="data row1 col2" >-0.29</td>
#       <td id="T_18779_row1_col3" class="data row1 col3" >0.16</td>
#       <td id="T_18779_row1_col4" class="data row1 col4" >-0.29</td>
#       <td id="T_18779_row1_col5" class="data row1 col5" >0.27</td>
#       <td id="T_18779_row1_col6" class="data row1 col6" >-0.25</td>
#       <td id="T_18779_row1_col7" class="data row1 col7" >0.27</td>
#       <td id="T_18779_row1_col8" class="data row1 col8" >-0.25</td>
#       <td id="T_18779_row1_col9" class="data row1 col9" >0.27</td>
#       <td id="T_18779_row1_col10" class="data row1 col10" >-0.25</td>
#       <td id="T_18779_row1_col11" class="data row1 col11" >0.27</td>
#       <td id="T_18779_row1_col12" class="data row1 col12" >-0.25</td>
#       <td id="T_18779_row1_col13" class="data row1 col13" >0.53</td>
#       <td id="T_18779_row1_col14" class="data row1 col14" >0.00</td>
#       <td id="T_18779_row1_col15" class="data row1 col15" >1.00</td>
#       <td id="T_18779_row1_col16" class="data row1 col16" >-0.31</td>
#       <td id="T_18779_row1_col17" class="data row1 col17" >0.15</td>
#       <td id="T_18779_row1_col18" class="data row1 col18" >-0.29</td>
#       <td id="T_18779_row1_col19" class="data row1 col19" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_18779_level1_row2" class="row_heading level1 row2" >2.000000</th>
#       <td id="T_18779_row2_col0" class="data row2 col0" >-0.27</td>
#       <td id="T_18779_row2_col1" class="data row2 col1" >0.32</td>
#       <td id="T_18779_row2_col2" class="data row2 col2" >-0.45</td>
#       <td id="T_18779_row2_col3" class="data row2 col3" >0.15</td>
#       <td id="T_18779_row2_col4" class="data row2 col4" >-0.29</td>
#       <td id="T_18779_row2_col5" class="data row2 col5" >0.16</td>
#       <td id="T_18779_row2_col6" class="data row2 col6" >-0.29</td>
#       <td id="T_18779_row2_col7" class="data row2 col7" >0.27</td>
#       <td id="T_18779_row2_col8" class="data row2 col8" >-0.25</td>
#       <td id="T_18779_row2_col9" class="data row2 col9" >0.27</td>
#       <td id="T_18779_row2_col10" class="data row2 col10" >-0.25</td>
#       <td id="T_18779_row2_col11" class="data row2 col11" >
